# %% [markdown]
# <a href="https://colab.research.google.com/github/Kidkudos77/CertChain/blob/main/PFx_Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/ PFx 2026-Team21-Chi & Carter /Javonte Carter Project"
# Out:
# /content/drive/.shortcut-targets-by-id/1r8mG2ucm52GUySdCHoUXzPVgl2kUmi5H/ PFx 2026-Team21-Chi & Carter /Javonte Carter Project

# %%
# !ls
# Out:
# PFx_Lab_1.ipynb

# %%
# !git pull
# Out:
# Already up to date.
